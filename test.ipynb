# %%
# %pip install gradio
# %pip install --upgrade pydantic
# %pip install torch
# Out:
# Requirement already satisfied: gradio in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (4.31.4)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from gradio) (23.2.1)
# Requirement already satisfied: altair<6.0,>=4.2.0 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from gradio) (5.3.0)
# Requirement already satisfied: fastapi in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from gradio) (0.103.2)
# Requirement already satisfied: ffmpy in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from gradio) (0.3.2)
# Requirement already satisfied: gradio-client==0.16.4 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from gradio) (0.16.4)
# Requirement already satisfied: httpx>=0.24.1 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from gradio) (0.27.0)
# Requirement already satisfied: huggingface-hub>=0.19.3 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from gradio) (0.21.4)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from gradio) (6.1.3)
# Requirement already satisfied: jinja2<4.0 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from gradio) (3.1.2)
# Requirement already satisfied: markupsafe~=2.0 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from gradio) (2.1.3)
# Requirement already satisfied: matplotlib~=3.0 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from gradio) (3.8.2)
# Requirement already satisfied: numpy~=1.0 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from gradio) (1.25.2)
# Requirement already satisfied: orjson~=3.0 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from gradio) (3.9.15)
# Requirement already satisfied: packaging in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from gradio) (23.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from gradio) (2.2.2)
# Requirement already satisfied: pillow<11.0,>=8.0 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from gradio) (10.1.0)
# Requirement already satisfied: pydantic>=2.0 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from gradio) (2.7.1)
# Requirement already satisfied: pydub in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from gradio) (0.0.9)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from gradio) (6.0.1)
# Requirement already satisfied: ruff>=0.2.2 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from gradio) (0.4.4)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from gradio) (0.12.0)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from gradio) (0.12.3)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from gradio) (4.11.0)
# Requirement already satisfied: urllib3~=2.0 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from gradio) (2.0.4)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from gradio) (0.29.0)
# Requirement already satisfied: fsspec in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from gradio-client==0.16.4->gradio) (2023.10.0)
# Requirement already satisfied: websockets<12.0,>=10.0 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from gradio-client==0.16.4->gradio) (11.0.3)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from altair<6.0,>=4.2.0->gradio) (4.19.2)
# Requirement already satisfied: toolz in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from altair<6.0,>=4.2.0->gradio) (0.12.1)
# Requirement already satisfied: anyio in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx>=0.24.1->gradio) (3.7.1)
# Requirement already satisfied: certifi in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx>=0.24.1->gradio) (2023.7.22)
# Requirement already satisfied: httpcore==1.* in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx>=0.24.1->gradio) (1.0.4)
# Requirement already satisfied: idna in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx>=0.24.1->gradio) (3.4)
# Requirement already satisfied: sniffio in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx>=0.24.1->gradio) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from huggingface-hub>=0.19.3->gradio) (3.12.3)
# Requirement already satisfied: requests in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from huggingface-hub>=0.19.3->gradio) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from huggingface-hub>=0.19.3->gradio) (4.66.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib~=3.0->gradio) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib~=3.0->gradio) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib~=3.0->gradio) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib~=3.0->gradio) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib~=3.0->gradio) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib~=3.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas<3.0,>=1.0->gradio) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas<3.0,>=1.0->gradio) (2023.3)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic>=2.0->gradio) (0.5.0)
# Requirement already satisfied: pydantic-core==2.18.2 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic>=2.0->gradio) (2.18.2)
# Requirement already satisfied: click>=8.0.0 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from typer<1.0,>=0.12->gradio) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from typer<1.0,>=0.12->gradio) (13.7.1)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from fastapi->gradio) (0.27.0)
# Requirement already satisfied: colorama in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.12.0)
# Requirement already satisfied: six>=1.5 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.16.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->huggingface-hub>=0.19.3->gradio) (3.2.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pydantic in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.7.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic) (0.5.0)
# Requirement already satisfied: pydantic-core==2.18.2 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic) (2.18.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic) (4.11.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: torch in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.2.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: filelock in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch) (3.12.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch) (2023.10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\nickk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sympy->torch) (1.3.0)

# %%
import gradio as gr
import torch
import torch.nn as nn
from joblib import load
import pandas as pd
import ipywidgets as widgets
from IPython.display import display

top_tags = pd.read_csv('data/top_tags.csv')
user_tags_dict = top_tags.groupby('userID')['tags'].apply(list).to_dict()


class ImprovedSongRecommender(nn.Module):
    def __init__(self, num_titles):
        super(ImprovedSongRecommender, self).__init__()
        self.fc1 = nn.Linear(2, 128)  # Adjusted input size
        self.bn1 = nn.BatchNorm1d(128)
        self.fc2 = nn.Linear(128, 256)
        self.bn2 = nn.BatchNorm1d(256)
        self.fc3 = nn.Linear(256, 128)
        self.bn3 = nn.BatchNorm1d(128)
        self.output = nn.Linear(128, num_titles)
        self.dropout = nn.Dropout(0.5)

    def forward(self, x):
        x = torch.relu(self.bn1(self.fc1(x)))
        x = self.dropout(x)
        x = torch.relu(self.bn2(self.fc2(x)))
        x = self.dropout(x)
        x = torch.relu(self.bn3(self.fc3(x)))
        x = self.dropout(x)
        x = self.output(x)
        return x


model_path = "improved_model.pth"
num_unique_titles = 4855

model = ImprovedSongRecommender(num_titles=num_unique_titles)
model.load_state_dict(torch.load(model_path, map_location=torch.device('cpu')))
model.eval()

label_encoders_path = "data/new_label_encoders.joblib"
scaler_path = "data/new_scaler.joblib"

label_encoders = load(label_encoders_path)
scaler = load(scaler_path)

index_to_song_title = {index: title for index,
                       title in enumerate(label_encoders['title'].classes_)}


def encode_input(tags, artist_name):
    tags = [tag.strip() for tag in tags.split(',')]
    artist_name = artist_name.strip().replace('\n', '')

    encoded_tags = []
    for tag in tags:
        try:
            encoded_tag = label_encoders['tags'].transform([tag])
        except ValueError:
            encoded_tag = label_encoders['tags'].transform(['unknown'])
        encoded_tags.extend(encoded_tag)

    # Pad or truncate the list of encoded tags to a fixed size
    encoded_tags = encoded_tags[:1]  # Truncate if more than 5 tags
    while len(encoded_tags) < 1:  # Pad with 'unknown' if fewer than 5 tags
        encoded_tags.append(label_encoders['tags'].transform(['unknown'])[0])

    if artist_name:
        try:
            encoded_artist = label_encoders['artist_name'].transform([artist_name])[
                0]
        except ValueError:
            encoded_artist = label_encoders['artist_name'].transform(['unknown'])[
                0]
    else:
        encoded_artist = label_encoders['artist_name'].transform(['unknown'])[
            0]

    return encoded_tags + [encoded_artist]


def recommend_songs(tags, user_id=None):
    try:
        if user_id is not None:
            tags = ', '.join(user_tags_dict.get(int(user_id), []))
        encoded_input = encode_input(tags, "")
        input_tensor = torch.tensor(encoded_input).float().unsqueeze(0)

        with torch.no_grad():
            output = model(input_tensor)

        recommendations_indices = torch.topk(
            output, 5).indices.squeeze().tolist()
        recommendations = [index_to_song_title.get(
            idx, "Unknown song") for idx in recommendations_indices]

        formatted_output = [
            f"Recommendation {i+1}: {rec}" for i, rec in enumerate(recommendations)]
        return formatted_output
    except Exception as e:
        return str(e)


interface = gr.Interface(
    fn=recommend_songs,
    inputs=[
        gr.Textbox(lines=1, placeholder="Enter Tags (e.g., rock)"),
        gr.Dropdown(choices=list(user_tags_dict.keys()),
                    label="User ID (optional)")
    ],
    outputs=gr.Textbox(label="Recommendations"),
    title="Music Recommendation System",
    description="Enter tags and (optionally) select a user ID to get music recommendations."
)

interface.launch()
# Out:
# C:\Users\Nickk\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.2.2 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# C:\Users\Nickk\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.2.2 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Running on local URL:  http://127.0.0.1:7879
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7879/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import pandas as pd
df = pd.read_csv('db/data/user_preferences.csv')

# %%
df = df[['userID', 'tags']]
df = df.dropna()

# %%
# Assuming 'tags' column contains the tags and 'userID' column contains the user IDs

# Split the tags into separate rows
df_tags = df.assign(tags=df['tags'].str.split(',')).explode('tags')

# Remove leading/trailing spaces
df_tags['tags'] = df_tags['tags'].str.strip()

# Get the top 20 tags for each user
top_tags = df_tags.groupby('userID')['tags'].apply(lambda x: x.value_counts().head(20)).reset_index()

# Rename the columns
top_tags.columns = ['userID', 'tag', 'count']

# Display the new DataFrame
top_tags = top_tags[['userID', 'tag']]

# %%
top_tags
# Out:
#      userID               tag
# 0         0              rock
# 1         0               pop
# 2         0      classic rock
# 3         0  female vocalists
# 4         0               80s
# ..      ...               ...
# 195       9               60s
# 196       9              Love
# 197       9       heavy metal
# 198       9            oldies
# 199       9  Progressive rock
#
# [200 rows x 2 columns]

# %%
df.to_csv('data/top_tags.csv', index=False)
